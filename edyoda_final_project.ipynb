# %% [markdown]
# # zomato vertuall database

# %%
food_items={}
FOOD=[]
food_history={}
admin_log={}
costomer_data={}
admin_login=[]
costomer_login=[]

# %%
# Out:
# ['463636', 'adiee@1']

# %%
class zomato():
  def __init__(self):
    global food_items
    global FOOD
    print("welcome to zomato Admin section")
    





  def add_item(self):
  
    self.name=input("please enter food name which you want to add")
    self.q=input("please enter food quantity")
    self.stock=input("please enter the no of total available stock in restraurant")
    self.price=input("please enter price of the product")
    self.id=self.name+"$"+self.q +"$"+self.stock+"$"+self.price
    self.id2=self.name+"-"+self.q +"-"+self.price+"[INR]"
    FOOD.append(self.id2)
    food_items[self.id]={"name_of_item":self.name,"quantity of each set":self.q,"no_of_unit_available":int(self.stock),"price_of_item/unit":int(self.price),"food_id":self.id}
    print("your id for your food product is:",self.id)
    self.n=input("Do you want to add new product?\n 1.press 1 for yes\n2. press 3 for showing all items in restrarants\n 3.press 2 for NO and exit")
    if self.n=="1":
      zomato.add_item(self)
    elif self.n=="2":
      for i in food_items.values():
        print(i)
    else:
      pass


  def edit_food(self):
    for i in food_items.values():
      print(i)

    while True:
      self.edit=input("please enter the food id of food which you want to edit")
      if self.edit in food_items:
        self.d=food_items[self.edit]
        print(self.d)
        print("---------------------------------------------------------------------------------------------------------------------------------------------------")
        self.edit2=input("what kind of alteration you want\n1.press 0 if want to edit name\n2.press 1 for edit the quantity of food per each unit \n3.press 2 for editing total stock quantity available in store\n4. press 3 if you want to change price of the product\n5. press 4 if you want to delete any items in menu ")
        if int(self.edit2) in range(4):
          self.hidden=["name_of_item","quantity of each set","no_of_unit_available","price_of_item/unit"]
          self.new_value=input("please enter the new value")
          self.d[self.hidden[int(self.edit2)]]=self.new_value
          print(self.d)
        else:
          for i in food_items.values():
            print(i)
          while True:
            self.new_value=input("please enter foodid of food which you want to delete")  
            if self.new_value in food_items:
              del food_items[self.new_value]
              print("your food product has been removed successfully")
              print("your updates menu is")
              for i in food_items.values():
                print(i)
              break
            else:
              print("please enter the correct id")



        break
      else:
        print("please enter correct food_id")





class zomato_c(zomato):
  def __init__(self):
    global food_history
    global FOOD
    print("Welcome to zomato")
    #self.name=n
    #self.number=pn
    #self.email=e
    #self.adress=a
    #self.password=p
  

  def start_up(self):
    self.big=[]
    while True:
      self.start=input("1. press 0 for PLACING NEW ORDER\n2. press 1 to show Privious order history\n3. press 2 To update the profile")
      if self.start=="0":
          print("please enter no of food product which you want to order")
          for i in range(len(FOOD)):
            print(i,".",FOOD[i])
          self.again=list(map(int,input().split(",")))
          print(self.again)
          for i in self.again:
            self.big.append(i)
          self.final=input("Do you want to place another order?\n 1.press 1 if yes \n2. press 2 if no")
          if self.final=="2":
            print("your order summery is following")
            self.bill=0
            self.tem=[]
            for i in self.big:
              print(FOOD[i])
              self.tem.append(FOOD[i])
              d=FOOD[i].split("-")
              d1=d[2]
              d2=d1.split("[INR]")
              self.bill=self.bill+int(d2[0])
              self.tem.append("total price="+str(self.bill))
            print("--------------------------")
            print("your total amount is=",self.bill)
            print("your order has been placed sucessfully")
            import datetime
            x = datetime.datetime.now()
            food_history[x.strftime("%c")]=self.tem

            break
        
      elif self.start=="1":
        for i in food_history.keys():
          print("order placed on=",i)
          for i in food_history[i]:
            print(i)
          print("-------------------------")
        break
      
      #elif self.start=="2":
        #self.c=["name","number","email","adress","password"]
        #self.choice=int(input("1.press 0 if you want to change a name\n2. press 1 if you want to chnage phone number\n3.press 2 if you want to change email \n4. press 3 if you want to chnage adresss\n5. press 4 if you want to chnage password"))
        #new=input("please enter new value")
        #self.d=self.c[self.choice]
        #mag=self.d
        #self.mag= new
        #break



f=input("1.PRESS 1 IF YOU ARE ADMIN\n2. PRESS 2 IF YOU ARE COSTOMER\n ")
if f=="1":
  i=input("if you are existing user press 1\n2. if you are new user press 2\n if you want to exit press3")
  if i=="1":
    while True:
      t=input("please enter your user name")
      if t in admin_login:
        y=input("plaease enter your password")
        if y in admin_login:
          print("your account has been created successfully\n")
          x=zomato()
          print("welcome to zomato Admin section")
          df=input("1. presss 1 if you want to add elements\n2.press 2 to edit items")
          if df=="1":
            x.add_item()
          elif df=="2":
            x.edit_food()

          break
        else:
          print("please enter correct login creadentials")

      else:
        print("please enter correct login creadentials")
        u=input("if you want to exit press 1\n2. if no press 2")
        if u=="1":
          break

  elif i=="2":
    b={}
    name=input("please enter your name")
    number=input("please enter your phone_number")
    email=input("please enter your email adress")
    adress=input("please enter your aadress")
    while True:
      user_id=input("please create your user_id ")
      if user_id not in admin_login:
        print("user id created ",user_id)
        password=input("please craete your password")
        if password not in admin_login:
          print("your password created sucessfully",password)
          admin_login.append(password)
          admin_login.append(user_id)
          b["name"]=name
          b["user_id"]=user_id
          b["phone_no"]=number
          b["email_id"]=email
          b["adress"]=adress
          b["password"]=password
          admin_log[user_id]=b

          break
        else:
          print("password already exist please craete diff password")
      else:
        print("password already exist please craete diff user id")


elif f=="2":
  i=input("if you are existing user press 1\n2. if you are new user press 2\n if you want to exit press3")
  if i=="1":
    while True:
      t=input("please enter your user name")
      if t in costomer_login:
        y=input("plaease enter your password")
        if y in costomer_login:
          yz=zomato_c()
          di=input("1.press 1 if you want to enter main app \n2. press 2 if you want to update profile")
          if di=="1":
            yz=zomato_c()
            yz.start_up()
          elif di=="2":
            f=["name","user_id","phone_no","email_id","adress","password"]
            log=costomer_data[t]
            ri=input("1.press 0 if you want to change a name\n2.press 1 if you want to change user id\n3. press 2 if you want to chnage phone number\n4.press 3 if you want to change email \n5. press 4 if you want to chnage adresss\n6. press 5 if you want to chnage password")  
            new=input("please enter new value which you want to enter")
            print("old data was ",costomer_data[t])
            if ri=="1":
              costomer_login.remove(t)
              costomer_login.append(new)
              costomer_data[t][f[int(ri)]]=new
              print("your new update profile=",costomer_data[t])

            elif ri=="5":
              costomer_login.remove(y)
              costomer_login.append(new)
              costomer_data[t][f[int(ri)]]=new
              print("your new update profile=",costomer_data[t])

            else:
              costomer_data[t][f[int(ri)]]=new
              print("your new update profile=",costomer_data[t])

            

          #print("welcome to zomato costomer section")

          break
        else:
          print("please enter correct login creadentials")

      else:
        print("please enter correct login creadentials")
        u=input("if you want to exit press 1\n2. if no press 2")
        if u=="1":
          break

  elif i=="2":
    b={}
    name=input("please enter your name")
    number=input("please enter your phone_number")
    email=input("please enter your email adress")
    adress=input("please enter your aadress")
    while True:
      user_id=input("please create your user_id ")
      if user_id not in costomer_login:
        print("user id created ",user_id)
        password=input("please craete your password")
        if password not in costomer_login:
          print("your password created sucessfully",password)
          costomer_login.append(password)
          costomer_login.append(user_id)
          b["name"]=name
          b["user_id"]=user_id
          b["phone_no"]=number
          b["email_id"]=email
          b["adress"]=adress
          b["password"]=password
          costomer_data[user_id]=b


          break
        else:
          print("password already exist please craete diff password")
      else:
        print("password already exist please craete diff user id")
# Out:
# please enter correct login creadentials
# please enter correct login creadentials
# please enter correct login creadentials
# please enter correct login creadentials
# Welcome to zomato
# Welcome to zomato
# please enter no of food product which you want to order

# %% [markdown]
# # ZOMATO COSTOMER  PART

# %%
class zomato_c(zomato):
  def __init__(self,n,pn,e,a,p):
    global food_history
    global FOOD
    print("Welcome to zomato")
    self.name=n
    self.number=pn
    self.email=e
    self.adress=a
    self.password=p
  

  def start_up(self):
    self.big=[]
    while True:
      self.start=input("1. press 0 for PLACING NEW ORDER\n2. press 1 to show Privious order history\n3. press 2 To update the profile")
      if self.start=="0":
          print("please enter no of food product which you want to order")
          for i in range(len(FOOD)):
            print(i,".",FOOD[i])
          self.again=list(map(int,input().split(",")))
          print(self.again)
          for i in self.again:
            self.big.append(i)
          self.final=input("Do you want to place another order?\n 1.press 1 if yes \n2. press 2 if no")
          if self.final=="2":
            print("your order summery is following")
            self.bill=0
            self.tem=[]
            for i in self.big:
              print(FOOD[i])
              self.tem.append(FOOD[i])
              d=FOOD[i].split("-")
              d1=d[2]
              d2=d1.split("[INR]")
              self.bill=self.bill+int(d2[0])
              self.tem.append("total price="+str(self.bill))
            print("--------------------------")
            print("your total amount is=",self.bill)
            print("your order has been placed sucessfully")
            import datetime
            x = datetime.datetime.now()
            food_history[x.strftime("%c")]=self.tem

            break
        
      elif self.start=="1":
        for i in food_history.keys():
          print("order placed on=",i)
          for i in food_history[i]:
            print(i)
          print("-------------------------")
        break
      
      elif self.start=="2":
        self.c=["name","number","email","adress","password"]
        self.choice=int(input("1.press 0 if you want to change a name\n2. press 1 if you want to chnage phone number\n3.press 2 if you want to change email \n4. press 3 if you want to chnage adresss\n5. press 4 if you want to chnage password"))
        new=input("please enter new value")
        self.d=self.c[self.choice]
        mag=self.d
        self.mag= new
        break




c=zomato_c(1,2,2,2,2)
print(c.name)
c.start_up()

# %%
f=input("1.PRESS 1 IF YOU ARE ADMIN\n2. PRESS 2 IF YOU ARE COSTOMER\n ")
if f=="1":
  i=input("if you are existing user press 1\n2. if you are new user press 2\n if you want to exit press3")
  if i=="1":
    while True:
      t=input("please enter your user name")
      if t in admin_login:
        y=input("plaease enter your password")
        if y in admin_login:
          x=

          break
        else:
          print("please enter correct login creadentials")

      else:
        print("please enter correct login creadentials")
        u=input("if you want to exit press 1\n2. if no press 2")
        if u=="1":
          break

  elif i=="2":
    b={}
    name=input("please enter your name")
    number=input("please enter your phone_number")
    email=input("please enter your email adress")
    adress=input("please enter your aadress")
    while True:
      user_id=input("please create your user_id ")
      if user_id not in admin_login:
        print("user id created ",user_id)
        password=input("please craete your password")
        if password not in admin_login:
          print("your password created sucessfully",password)
          admin_login.append(password)
          admin_login.append(user_id)
          b["name"]=name
          b["user_id"]=user_id
          b["phone_no"]=number
          b["email_id"]=email
          b["adress"]=adress
          b["password"]=password
          admin_log[user_id]=b

          break
        else:
          print("password already exist please craete diff password")
      else:
        print("password already exist please craete diff user id")
elif i=="2":
  i=input("if you are existing user press 1\n2. if you are new user press 2\n if you want to exit press3")
  if i=="1":
    while True:
      t=input("please enter your user name")
      if t in costomer_login:
        y=input("plaease enter your password")
        if y in costomer_login:
          break
        else:
          print("please enter correct login creadentials")

      else:
        print("please enter correct login creadentials")
        u=input("if you want to exit press 1\n2. if no press 2")
        if u=="1":
          break

  elif i=="2":
    b={}
    name=input("please enter your name")
    number=input("please enter your phone_number")
    email=input("please enter your email adress")
    adress=input("please enter your aadress")
    while True:
      user_id=input("please create your user_id ")
      if user_id not in costomer_login:
        print("user id created ",user_id)
        password=input("please craete your password")
        if password not in costomer_login:
          print("your password created sucessfully",password)
          costomer_login.append(password)
          costomer_login.append(user_id)
          b["name"]=name
          b["user_id"]=user_id
          b["phone_no"]=number
          b["email_id"]=email
          b["adress"]=adress
          b["password"]=password
          costomer_data[user_id]=b


          break
        else:
          print("password already exist please craete diff password")
      else:
        print("password already exist please craete diff user id")
